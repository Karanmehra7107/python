# %% [markdown]
#                           data  read
# data
# data.head()  # top 5 rows function
# .columns
# data.tail()
# data.shape # rwos*columns (.shape=atribute)
# .shape[0] # for row
# .shape[1] # column
# data.info()  # check non null values and data type and memory usage  (NaN=Intiger/object, null='string')
# data.describe()  # numerical values analysis
# data.value_count()  # only for catagorical values count (non unique count)
#
#                        fetching  columns
# data['column name']  # always 1 column in series[]
# data[['column 1','column 2','column 3']]   # 1+ object always in list[['','']]
#
#                        fetching  rows
# data.iloc['']  # always 1 parameter in series
# data.iloc[1:3] # 0 index row to 3 show all
# data.iloc[[1:5:6]]  # rows acc to index no
#
#                     filtering dataframe on a condition
#   mask=data['column name']=='value'    # fetch value from rows and column with specific value
#   data[mask]
# eg: mask=data['city']=='hydrebad'
#     data[mask]
#     data[mask].shape
#
#                     creating function for city count
# def get_city_match_count(city)         # inspite of writing again & again condition fitering creat def function
#     mask=data['city']==city
#     return data[mask]
#
#
#                     furtehrt for 2 conditions
# mask1=data['city']=='hydrebad'
# mask2=data['date']>2010.1.1
# data[mask1 & mask2].shape[0]    # & bitwise operator for boolean typte , .shape 0= rows,1=column
#
# def get_column_by_city_date(data)
#     mask1=data['city']=='hydrebad'
#     mask2=data['date']>2010.1.1
# return data[mask1 & mask2].shape[0]
#
#                       Unique count
# data['winner'].value_counts()  # for series(How namy matches won by  each team??) # only for catagorical values
#
#                       pandas plot

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('matches.csv')
data.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
data['team1']
# Out:
# 0              Sunrisers Hyderabad
# 1                   Mumbai Indians
# 2                    Gujarat Lions
# 3           Rising Pune Supergiant
# 4      Royal Challengers Bangalore
#                   ...
# 751          Kolkata Knight Riders
# 752            Chennai Super Kings
# 753            Sunrisers Hyderabad
# 754                 Delhi Capitals
# 755                 Mumbai Indians
# Name: team1, Length: 756, dtype: object

# %%
data[['team1','team2','winner']]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 751        Kolkata Knight Riders               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753          Sunrisers Hyderabad               Delhi Capitals
# 754               Delhi Capitals          Chennai Super Kings
# 755               Mumbai Indians          Chennai Super Kings
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
data.iloc[1:3]
# Out:
#    id    Season    city        date           team1                   team2  \
# 1   2  IPL-2017    Pune  06-04-2017  Mumbai Indians  Rising Pune Supergiant
# 2   3  IPL-2017  Rajkot  07-04-2017   Gujarat Lions   Kolkata Knight Riders
#
#               toss_winner toss_decision  result  dl_applied  \
# 1  Rising Pune Supergiant         field  normal           0
# 2   Kolkata Knight Riders         field  normal           0
#
#                    winner  win_by_runs  win_by_wickets player_of_match  \
# 1  Rising Pune Supergiant            0               7       SPD Smith
# 2   Kolkata Knight Riders            0              10         CA Lynn
#
#                                      venue         umpire1    umpire2 umpire3
# 1  Maharashtra Cricket Association Stadium  A Nand Kishore     S Ravi     NaN
# 2   Saurashtra Cricket Association Stadium     Nitin Menon  CK Nandan     NaN

# %%
mask=data['city']=='Hyderabad'
mask1=data['date']<'31-10-2019' 
data[mask & mask1]
# Out:
#         id    Season       city        date                  team1  \
# 0        1  IPL-2017  Hyderabad  05-04-2017    Sunrisers Hyderabad
# 5        6  IPL-2017  Hyderabad  09-04-2017          Gujarat Lions
# 18      19  IPL-2017  Hyderabad  17-04-2017    Sunrisers Hyderabad
# 20      21  IPL-2017  Hyderabad  19-04-2017    Sunrisers Hyderabad
# 35      36  IPL-2017  Hyderabad  30-04-2017    Sunrisers Hyderabad
# ..     ...       ...        ...         ...                    ...
# 725  11321  IPL-2019  Hyderabad  14-04-2019         Delhi Capitals
# 728  11324  IPL-2019  Hyderabad  17-04-2019    Chennai Super Kings
# 733  11329  IPL-2019  Hyderabad  21-04-2019  Kolkata Knight Riders
# 743  11339  IPL-2019  Hyderabad  29-04-2019    Sunrisers Hyderabad
# 755  11415  IPL-2019  Hyderabad  12-05-2019         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
def city_data(city):
    mask=data['city']==city
    return data[mask]

# %%
city_data('Indore').shape[0]
# Out:
# 9

# %%
city_data('Hyderabad')
# Out:
#         id    Season       city        date                  team1  \
# 0        1  IPL-2017  Hyderabad  05-04-2017    Sunrisers Hyderabad
# 5        6  IPL-2017  Hyderabad  09-04-2017          Gujarat Lions
# 18      19  IPL-2017  Hyderabad  17-04-2017    Sunrisers Hyderabad
# 20      21  IPL-2017  Hyderabad  19-04-2017    Sunrisers Hyderabad
# 35      36  IPL-2017  Hyderabad  30-04-2017    Sunrisers Hyderabad
# ..     ...       ...        ...         ...                    ...
# 725  11321  IPL-2019  Hyderabad  14-04-2019         Delhi Capitals
# 728  11324  IPL-2019  Hyderabad  17-04-2019    Chennai Super Kings
# 733  11329  IPL-2019  Hyderabad  21-04-2019  Kolkata Knight Riders
# 743  11339  IPL-2019  Hyderabad  29-04-2019    Sunrisers Hyderabad
# 755  11415  IPL-2019  Hyderabad  12-05-2019         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
city_data('Hyderabad')
# Out:
#         id    Season       city        date                  team1  \
# 0        1  IPL-2017  Hyderabad  05-04-2017    Sunrisers Hyderabad
# 5        6  IPL-2017  Hyderabad  09-04-2017          Gujarat Lions
# 18      19  IPL-2017  Hyderabad  17-04-2017    Sunrisers Hyderabad
# 20      21  IPL-2017  Hyderabad  19-04-2017    Sunrisers Hyderabad
# 35      36  IPL-2017  Hyderabad  30-04-2017    Sunrisers Hyderabad
# ..     ...       ...        ...         ...                    ...
# 725  11321  IPL-2019  Hyderabad  14-04-2019         Delhi Capitals
# 728  11324  IPL-2019  Hyderabad  17-04-2019    Chennai Super Kings
# 733  11329  IPL-2019  Hyderabad  21-04-2019  Kolkata Knight Riders
# 743  11339  IPL-2019  Hyderabad  29-04-2019    Sunrisers Hyderabad
# 755  11415  IPL-2019  Hyderabad  12-05-2019         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
mask=data['winner']=='Sunrisers Hyderabad'
data[mask].shape[0]
# Out:
# 58

# %%
data['winner'].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Delhi Capitals                  10
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %% [markdown]
#                        pandas plot
# from matplotlib import pyplot as plt
# or  import matplotlib.pyplot as plt
#
#
# bar chart= for catagorical data
# histogram chart= for numerical data
# data['winner'].value_counts().head().plot(kind='bar')
#
#                       adding 2 series with index no
# x= data['team1'].value_counts()+data['team2'].value_counts()  # total no of matches by each team
# x
#
#                       sorting
# .sort_values(ascending=False)
#
#                      .drop_duplicates()
# .drop_duplicates(subest=['city'], inplace=True)    # inplace true for parmament change in dataset

# %%
from matplotlib import pyplot as plt
data['winner'].value_counts().head().plot(kind='bar')

# %%
data['winner'].value_counts().head()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Name: winner, dtype: int64

# %%
data.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data['win_by_runs'].plot(kind='hist')

# %%
x= data['team1'].value_counts()+data['team2'].value_counts()
x.sort_values(ascending=False)
# Out:
# Mumbai Indians                 187
# Royal Challengers Bangalore    180
# Kolkata Knight Riders          178
# Kings XI Punjab                176
# Chennai Super Kings            164
# Delhi Daredevils               161
# Rajasthan Royals               147
# Sunrisers Hyderabad            108
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Delhi Capitals                  16
# Rising Pune Supergiants         14
# Kochi Tuskers Kerala            14
# dtype: int64

# %%
x.sort_values(ascending=False).plot(kind='barh')

# %%
x.sort_values(ascending=False).plot(kind='pie',figsize=(10,10),title='total matches played by each team')

# %%
## sorting

# %%
x.sort_values(ascending=False)
# Out:
# Mumbai Indians                 187
# Royal Challengers Bangalore    180
# Kolkata Knight Riders          178
# Kings XI Punjab                176
# Chennai Super Kings            164
# Delhi Daredevils               161
# Rajasthan Royals               147
# Sunrisers Hyderabad            108
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Delhi Capitals                  16
# Rising Pune Supergiants         14
# Kochi Tuskers Kerala            14
# dtype: int64

# %%
x.sort_values(ascending=True).plot(kind='barh')

# %%
z=data.drop_duplicates(subset=['city'])
z
# Out:
#        id    Season            city        date                        team1  \
# 0       1  IPL-2017       Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1       2  IPL-2017            Pune  06-04-2017               Mumbai Indians
# 2       3  IPL-2017          Rajkot  07-04-2017                Gujarat Lions
# 3       4  IPL-2017          Indore  08-04-2017       Rising Pune Supergiant
# 4       5  IPL-2017       Bangalore  08-04-2017  Royal Challengers Bangalore
# 6       7  IPL-2017          Mumbai  09-04-2017        Kolkata Knight Riders
# 10     11  IPL-2017         Kolkata  13-04-2017              Kings XI Punjab
# 14     15  IPL-2017           Delhi  15-04-2017             Delhi Daredevils
# 31     32  IPL-2017      Chandigarh  28-04-2017          Sunrisers Hyderabad
# 48     49  IPL-2017          Kanpur  10-05-2017                Gujarat Lions
# 64     65  IPL-2008          Jaipur  21-04-2008              Kings XI Punjab
# ...

# %%
y=data['city'].value_counts().sort_values(ascending=True).plot(kind='barh',figsize=(10,10),title='')
y

# %%
# groupby()

# %%
runs=data.groupby('player_of_match')
runs

# %%
runs.get_group('Yuvraj Singh')
# Out:
#       id    Season          city        date                        team1  \
# 0      1  IPL-2017     Hyderabad  05-04-2017          Sunrisers Hyderabad
# 138  139  IPL-2009        Durban  01-05-2009  Royal Challengers Bangalore
# 163  164  IPL-2009  Johannesburg  17-05-2009              Kings XI Punjab
# 249  250  IPL-2011        Mumbai  17-04-2011                Pune Warriors
# 494  495  IPL-2014     Bangalore  13-05-2014  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 138              Kings XI Punjab  Royal Challengers Bangalore           bat
# 163              Deccan Chargers              Deccan Chargers         field
# 249             Delhi Daredevils             Delhi Daredevils         field
# 494             Delhi Daredevils             Delhi Daredevils         field
#
# ...

# %% [markdown]
#                      merging dataframes columns
# data1.merge(data2,left_on='1column name',right_on='2column name')
# data1 = 1colmn name = left_on | data2 = 2colmn name = right_on
#
#                      pivot table

# %%
pt=data.pivot_table(values='win_by_runs', index='city', columns='venue', aggfunc='mean')
pt
# Out:
# venue           ACA-VDCA Stadium  Barabati Stadium  Brabourne Stadium  \
# city
# Abu Dhabi                    NaN               NaN                NaN
# Ahmedabad                    NaN               NaN                NaN
# Bangalore                    NaN               NaN                NaN
# Bengaluru                    NaN               NaN                NaN
# Bloemfontein                 NaN               NaN                NaN
# Cape Town                    NaN               NaN                NaN
# Centurion                    NaN               NaN                NaN
# Chandigarh                   NaN               NaN                NaN
# Chennai                      NaN               NaN                NaN
# Cuttack                      NaN         10.428571                NaN
# Delhi                        NaN               NaN                NaN
# Dharamsala                   NaN               NaN                NaN
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(pt)

# %% [markdown]
#                     correlation
#     .corr()

# %%
pt.corr()
# Out:
# venue                                               ACA-VDCA Stadium  \
# venue
# ACA-VDCA Stadium                                                 NaN
# Barabati Stadium                                                 NaN
# Brabourne Stadium                                                NaN
# Buffalo Park                                                     NaN
# De Beers Diamond Oval                                            NaN
# Dr DY Patil Sports Academy                                       NaN
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...               NaN
# Eden Gardens                                                     NaN
# Feroz Shah Kotla                                                 NaN
# Feroz Shah Kotla Ground                                          NaN
# Green Park                                                       NaN
# Himachal Pradesh Cricket Association Stadium                     NaN
# ...

# %%
sns.heatmap(pt.corr())

# %% [markdown]
#                 handeling missing values
#                 dropna()

# %%
d=pd.read_csv('train.csv')
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
d.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
m=d.dropna()
m
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
m.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
m.shape
# Out:
# (183, 12)

# %%
## drop in paticular column

# %%
d.dropna(subset=['Cabin']).shape
# Out:
# (204, 12)

# %%
# fillna()

# %%
d.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
d['Cabin'].fillna('not specified')
# Out:
# 0      not specified
# 1                C85
# 2      not specified
# 3               C123
# 4      not specified
#            ...
# 886    not specified
# 887              B42
# 888    not specified
# 889             C148
# 890    not specified
# Name: Cabin, Length: 891, dtype: object
